# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from astropy.io import fits

# %%
imagename = 'combine-substracted.J0423-0120.ms.automask2.cont.fits'

# %%
hdu_list = fits.open(imagename)

# %%
hdu_list.info()
# Out:
# Filename: combine-substracted.J0423-0120.ms.automask2.cont.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      80   (768, 768, 1, 1)   float32

# %%
image_data = hdu_list[0].data

# %%
print type(image_data)
print image_data.shape
# Out:
# <type 'numpy.ndarray'>
# (1, 1, 768, 768)

# %%
image_data[0][0].shape
# Out:
# (768, 768)

# %%
img = image_data[0][0]

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img, cmap='gray')
plt.colorbar()

# %%
NBINS = 1000
flatimg = img.flatten()

# %%
flatimg = flatimg[~np.isnan(flatimg)] # remove nan

# %%
histogram = plt.hist(flatimg, 1000)

# %%
plt.imshow(img)

# I chose the tick marks based on the histogram above
cbar = plt.colorbar(ticks=[3e-05,12e-05,3e-03])
cbar.ax.set_yticklabels([3e-05,12e-05,3e-03])

# %%
# %pwd
# Out:
# u'/home/ridlo'
