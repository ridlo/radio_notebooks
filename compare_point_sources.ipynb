# %%
import sys
sys.path.insert(0,'/home/ridlo/radio/alma-calibrator/src')

# %%
from compareImage import *
# %matplotlib inline

# %%
ifile = 'point_source.dat'

# %%
position = coordinates.SkyCoord('05h22m57.98465s', '-36d27m30.8509s', frame='icrs') # PKS 0521-035

# %%
CI = CompareImage()

points = CI.read_data_points(ifile)
surveys = ['DSS', '2MASS-K', '2MASS-J', 'WISE 22', 'WISE 3.4']
images = CI.get_images(position, 1.0, surveys) # radius 1 arcmin

for i, s in enumerate(surveys):
    CI.overplot_points_to_image(points, images[i], ofile=s+'_and_pointSources.png')
# Out:
# /home/ridlo/anaconda2/lib/python2.7/site-packages/matplotlib/artist.py:221: MatplotlibDeprecationWarning: This has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   warnings.warn(_get_axes_msg, mplDeprecation, stacklevel=1)
# /home/ridlo/anaconda2/lib/python2.7/site-packages/aplpy/labels.py:432: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self.coord == x or self.axis.apl_tick_positions_world[ipos] > 0:
# INFO: Auto-setting vmin to  1.908e+03 [aplpy.core]
# INFO: Auto-setting vmax to  2.003e+04 [aplpy.core]
# INFO: Auto-setting vmin to  5.206e+02 [aplpy.core]
# INFO: Auto-setting vmax to  6.445e+02 [aplpy.core]
# INFO: Auto-setting vmin to  9.321e+01 [aplpy.core]
# INFO: Auto-setting vmax to  1.616e+02 [aplpy.core]
# INFO: Auto-setting vmin to  7.848e+01 [aplpy.core]
# INFO: Auto-setting vmax to  9.474e+01 [aplpy.core]
# ...
