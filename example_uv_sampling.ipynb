# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def fringe(uv, x, y):
    res = 0.0
    for i,u in enumerate(uv): 
        res += np.cos(2*np.pi*(uv[i][0]*x/206265 + uv[i][1]*y/206265)) # in arcsec
        
    return res

# %% [markdown]
# ### 2 antenna

# %%
uv = np.array([[150000, 300000]])

# %%
n = 256
x = np.linspace(-5, 5, n) 
y = np.linspace(-5, 5, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, fringe(uv, X, Y), 8, alpha=.75, cmap='hot')

# %%
# uv-plane
plt.plot(uv[:,0], uv[:,1], 'b.')
plt.plot(-uv[:,0], -uv[:,1], 'b.')
plt.xlim([-500000, 500000])
plt.ylim([-500000, 500000])
# Out:
# (-500000, 500000)

# %% [markdown]
# ### 3 antenna

# %%
uv = np.array([[150000, 300000], [50000, -150000], [200000, 200000]])

# %%
n = 256
x = np.linspace(-5, 5, n) 
y = np.linspace(-5, 5, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, fringe(uv, X, Y), 8, alpha=.75, cmap='hot')

# %%
# uv-plane
plt.plot(uv[:,0], uv[:,1], 'b.')
plt.plot(-uv[:,0], -uv[:,1], 'b.')
plt.xlim([-500000, 500000])
plt.ylim([-500000, 500000])
# Out:
# (-500000, 500000)

# %% [markdown]
# ### 5 antenna

# %%
uv = np.array([[150000, 300000], [50000, -150000], [200000, 200000], [75000, 200000], [200000, -50000]])

# %%
n = 256
x = np.linspace(-5, 5, n) 
y = np.linspace(-5, 5, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, fringe(uv, X, Y), 8, alpha=.75, cmap='hot')

# %%
# uv-plane
plt.plot(uv[:,0], uv[:,1], 'b.')
plt.plot(-uv[:,0], -uv[:,1], 'b.')
plt.xlim([-500000, 500000])
plt.ylim([-500000, 500000])
# Out:
# (-500000, 500000)

# %% [markdown]
# ### Random position (300x2 uv sampling), unrealistic

# %%
uv = -200000 + 400000*np.random.rand(300,2)

# %%
n = 256
x = np.linspace(-5, 5, n) 
y = np.linspace(-5, 5, n)
X, Y = np.meshgrid(x, y)

plt.contourf(X, Y, fringe(uv, X, Y), 8, alpha=.75, cmap='hot')

# %%
# uv-plane
plt.plot(uv[:,0], uv[:,1], 'b.')
plt.plot(-uv[:,0], -uv[:,1], 'b.')
